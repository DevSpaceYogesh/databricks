# %%
# %sql
select sf.city, count(rv.review) no_of_reviews from samples.bakehouse.media_customer_reviews rv, samples.bakehouse.sales_franchises sf where rv.franchiseID = sf.franchiseID group by sf.city

# %%
# %sql
select * from samples.bakehouse.sales_franchises ;

# %%
# %sql
select count(*) from samples.bakehouse.sales_customers

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", -1)

# %%
#samples.bakehouse.media_customer_reviews rv, samples.bakehouse.sales_franchises sf 
df_review = spark.read.table("samples.bakehouse.media_customer_reviews")
df_franchies = spark.read.table("samples.bakehouse.sales_franchises")
df_data=df_review.join(df_franchies,df_review.franchiseID==df_franchies.franchiseID)
df_data.explain("formatted")
#df_data_filter= df_data.filter("pickup_zip=10024").groupBy("dropoff_zip").count()
#df_data.explain("formatted")
